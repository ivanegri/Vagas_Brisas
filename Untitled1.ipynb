# %%
import pandas as pd

# %%
df = pd.read_csv('relacao_de_vagas.csv')

# %%
df
# Out:
#      Unnamed: 0 Unidade        2020        2021        2022        2023  \
# 0             0     1-1  Descoberta  Descoberta     Coberta  Descoberta
# 1             1   1-101     Coberta  Descoberta  Descoberta  Descoberta
# 2             2   1-102  Descoberta  Descoberta  Descoberta     Coberta
# 3             3   1-103     Coberta  Descoberta  Descoberta  Descoberta
# 4             4   1-104  Descoberta     Coberta  Descoberta     Coberta
# ..          ...     ...         ...         ...         ...         ...
# 295         295    3-92  Descoberta  Descoberta  Descoberta     Coberta
# 296         296    3-93  Descoberta  Descoberta  Descoberta     Coberta
# 297         297    3-94  Descoberta  Descoberta     Coberta  Descoberta
# 298         298    3-95  Descoberta  Descoberta  Descoberta  Descoberta
# 299         299    3-96  Descoberta  Descoberta  Descoberta     Coberta
#
#            2024
# 0    Descoberta
# 1       Coberta
# 2    Descoberta
# 3       Coberta
# ...

# %%
fd = pd.read_csv('modelo_pne_regular.csv')

# %%
final = df.merge(fd, on='Unidade')

# %%
final.drop(columns={'Unnamed: 0_x','Unnamed: 0_y'},inplace=True)

# %%
final.to_csv('relacao_de_vagas.csv')

# %%
final
# Out:
#     Unidade        2020        2021        2022        2023        2024  \
# 0       1-1  Descoberta  Descoberta     Coberta  Descoberta  Descoberta
# 1     1-101     Coberta  Descoberta  Descoberta  Descoberta     Coberta
# 2     1-102  Descoberta  Descoberta  Descoberta     Coberta  Descoberta
# 3     1-103     Coberta  Descoberta  Descoberta  Descoberta     Coberta
# 4     1-104  Descoberta     Coberta  Descoberta     Coberta  Descoberta
# ..      ...         ...         ...         ...         ...         ...
# 295    3-92  Descoberta  Descoberta  Descoberta     Coberta  Descoberta
# 296    3-93  Descoberta  Descoberta  Descoberta     Coberta  Descoberta
# 297    3-94  Descoberta  Descoberta     Coberta  Descoberta  Descoberta
# 298    3-95  Descoberta  Descoberta  Descoberta  Descoberta     Coberta
# 299    3-96  Descoberta  Descoberta  Descoberta     Coberta  Descoberta
#
#     Tipo Vaga
# 0     Regular
# 1     Regular
# 2     Regular
# 3     Regular
# 4     Regular
# ...
